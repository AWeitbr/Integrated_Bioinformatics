# %% [markdown]
# General review:
#
# https://genomebiology.biomedcentral.com/articles/10.1186/gb-2003-4-4-210
#
# (doi:10.1186/gb-2003-4-4-210)

# %% [markdown]
# ## Subtask 0: Download the data

# %% [markdown]
# General imports

# %%
# %matplotlib inline

# %%
import sys
import os

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from scipy.stats import pearsonr
from scipy.stats import bartlett, levene, normaltest, mannwhitneyu
from scipy.stats.mstats import zscore
from statsmodels.sandbox.stats.multicomp import multipletests
import statsmodels.graphics.gofplots as sm
import random

# %%
DIR = "InOutDirectory/"

# %% [markdown]
# hint:
#
# http://science.sciencemag.org/highwire/filestream/680254/field_highwire_adjunct_files/5/aad0189_DataFileS5.xlsx

# %%
# !wget -O $DIR"ExpressionData.xlsx" "http://science.sciencemag.org/highwire/filestream/680254/field_highwire_adjunct_files/5/aad0189_DataFileS5.xlsx"

# %% [markdown]
# ## Task 1: Data wrangling

# %% [markdown]
# hint:
#
# http://www.arrayanalysis.org/main.html

# %% [markdown]
# ### Subtask 1.1: Read in aad0189_DataFileS5.xlsx with pandas

# %%
exprData = pd.read_excel(DIR + "ExpressionData.xlsx", header=2)

# %%
exprData.head()
# Out:
#    Original_Order  MATCH_ORDER     Gene  Probeset   Gene.1 Protein  \
# 0           12643          NaN      Igh  10403036      Igh       0
# 1           12646          NaN      Igh  10403043      Igh       0
# 2           12653          NaN      Igh  10403063      Igh       0
# 3            8759       1458.0    Hcfc2  10365242    Hcfc2  A0AUN4
# 4           18740       8191.0  Ccdc112  10458794  Ccdc112  A0AUP1
#
#    Unnamed: 6  Range CD  Range HFD  Range_All        ...         \
# 0         NaN  1.495886   1.720705   1.720705        ...
# 1         NaN  2.938337   1.988940   3.595021        ...
# 2         NaN  3.719220   1.859610   4.260433        ...
# 3         NaN  1.479388   1.465101   1.536875        ...
# 4         NaN  1.834008   1.943962   1.997229        ...
#
#    BXD89_Liver_HFD  BXD90_Liver_HFD  BXD95_Liver_HFD  BXD96_Liver_HFD  \
# 0            4.959            5.483            5.347            5.087
# ...

# %% [markdown]
# ### Subtask 1.2: Average over different probesets for a gene and generate a dataframe containing each gene symbol (once)  as rows and the corresponding averaged expression values for each strain + condition as columns

# %%
avExprData = exprData.groupby("Gene", sort=False).mean()

# %%
avExprData.head()
# Out:
#           Original_Order  MATCH_ORDER    Probeset  Unnamed: 6  Range CD  \
# Gene
# Igh              12641.0          NaN  10403001.5         NaN  2.524014
# Hcfc2             8759.0       1458.0  10365242.0         NaN  1.479388
# Ccdc112          18740.0       8191.0  10458794.0         NaN  1.834008
# EG635895         16962.0          NaN  10441899.0         NaN  1.937236
# Srp72            25569.0      12857.0  10522676.0         NaN  1.582275
#
#           Range HFD  Range_All  C57BL/6J_Liver_CD  DBA/2J_Liver_CD  \
# Gene
# Igh        1.780279   3.047875            6.92575           6.7715
# Hcfc2      1.465101   1.536875            9.24100           8.9900
# Ccdc112    1.943962   1.997229            6.76100           6.6560
# EG635895   1.699370   2.168955            6.68900           6.4560
# Srp72      1.419123   1.584470           11.44200          11.3130
#
#           BXD43_Liver_CD        ...         BXD89_Liver_HFD  BXD90_Liver_HFD  \
# ...

# %% [markdown]
# ### Subtask 1.3: Quantile normalization: carry out a quantile normalization of the data (or not)

# %% [markdown]
# #### Subsubtask 1.3.1: Implement a ratio intensity plot (using matplotlib)

# %%
def ratioIntensityPlot(a, b):
    '''
    Function which plots a ratio intensity plot of a pandas dataframe
    
    a,b
        list or np.array which contain the expression values of the two samples
        
    visual output of a plot
    '''
    # initialise the plot
    plt.figure(figsize=(15,8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")
    
    # convert a and b into np.arrays if they are non of those
    a = np.array(a)
    b = np.array(b)
    
    # compute the r and i values
    r = np.log10(a / b)
    i = (np.log(a) + np.log(b)) / 2

    # create the scatter plot
    plt.scatter(i, r)
    # draw a horizontal line
    plt.axhline(0, 0, color="black")
    
    # visual settings and output of the plot
    plt.xlabel("Intensity", fontsize=16)
    plt.ylabel("Ratio", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(True, color="lightgrey")
    plt.title("Ratio-Intensity plot", fontsize=18)
    plt.show();

# %% [markdown]
# #### Subsubtask 1.3.2: Apply your ratio intensity plot to several pairs of chips (columns of your above dataframe)

# %%
ratioIntensityPlot(avExprData["BXD96_Liver_HFD"].values, avExprData["BXD99_Liver_HFD"].values)

# %%
ratioIntensityPlot(avExprData["BXD43_Liver_CD"].values, avExprData["BXD103_Liver_HFD"].values)

# %%
ratioIntensityPlot(avExprData["C57BL/6J_Liver_CD"].values, avExprData["BXD95_Liver_HFD"].values)

# %% [markdown]
# #### Subsubtask 1.3.3: Implement a rle plot (rle = relative log expression)

# %%
def rlePlot(df):
    '''
    Function which plots a relative log expression plot of a pandas dataframe
    
    df
        pandas dataframe which just contains the expression values and has the gene name as indices
        
    visual output of a plot
    '''
    # initialise the plot
    plt.figure(figsize=(15,8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")  
    
    # draw the boxplots for the transposed dataframe (to have one boxplot per gene) and all "gene" expression
    # values divided by the median over all genes
    medianDF = (df.T / df.T.median())
    sns.boxplot(data=np.log10(medianDF.T))
    
    # visual settings and output of the plot
    plt.xlabel("Samples", fontsize=16)
    plt.ylabel("-log$_{10}($Expression$ / $Median(Expression)$)$", fontsize=16)
    plt.xticks(fontsize=10, rotation="vertical")
    plt.yticks(fontsize=14)
    plt.grid(True, color="lightgrey")
    plt.title("Relative log expression plot", fontsize=18)
    plt.show();

# %% [markdown]
# #### Subsubtask 1.3.4: Apply your RLE plot to the data
# Small test example for two samples and five genes

# %%
rlePlot(avExprData[["BXD43_Liver_CD","BXD103_Liver_HFD"]].head())

# %% [markdown]
# RLE Plot for all genes and all samples. For easier usage of the samples, create a smaller sub DataFrame which does not contain the unneccessary rows.

# %%
editAvExprData = avExprData.copy()
editAvExprData.drop(["Original_Order", "MATCH_ORDER", "Probeset", "Unnamed: 6", 
                     "Unnamed: 51", "Range CD", "Range HFD", "Range_All"], axis=1, inplace=True)

# %%
rlePlot(editAvExprData)

# %% [markdown]
# #### Subsubtask 1.3.5: If you consider it necessary, perform a quantile normalization of the data

# %% [markdown]
# Due to the look of the RLE plot, with the small variance of the median over all samples a quantile normalisation should not be neccessary, the data look quite normalised. The random Ratio-Intensity plots with a guessed regression line very close to the drawn horizontal confirmes this decision.

# %% [markdown]
# ## Task 2: Which statistical test to chose?

# %% [markdown]
# We want to infer differentially expressed genes between the CD and the HFD condition. Therefore we (mis)(?)treat (!) the (already) normalized expression values of all the strains for a given condition as independent observations of the same sample. But first we need to figure out which statistical test for differential expression seems appropriate (concerning distribution and variance assumptions) and then apply it. Limit yourself to the Student t-test, the Welch t-test or Wilcoxon's rank-sum test (also sometimes refered to as Whitney-Mann U-test).
#
# Everything you may need, is most likely found here:
#
# http://docs.scipy.org/doc/scipy-0.17.1/reference/stats.html
#
# http://statsmodels.sourceforge.net/stable/graphics.html

# %% [markdown]
# ### Subtask 2.1: Do the CD and HFD samples have equal variance?

# %% [markdown]
# Josef-Francisco Del-Marre-Doyle, famous and visionary president of the International BXD Society (IBXDS), just gave a celebrated TED-talk in which he reviewed the fact that any statistic associated with the universe is almost surely normally distributed, and hence you canonically assume that the only thing left to check is whether the samples have equal variance, that is whether to apply Student's or Welch's t-test. Josef-Francisco's assessment usually is that "things are equal" and so you're quite confident that you'll be able to use Student's t-test. But since you're an excellent scientist (and, additionally, won't pass the course otherwise) you still do the following certainly unnecessary work:

# %% [markdown]
# #### Subsubtask 2.1.1: Choose a random row of your latest dataframe using the random module of Python

# %%
randGene = str(random.choice(list(editAvExprData.index.values)))
randGene
# Out:
# '2510009E07Rik'

# %% [markdown]
# #### Subsubtask 2.1.2: Make a Q-Q plot comparing the two samples for the just chosen gene and answer the question: Does this tell you anything?

# %% [markdown]
# Prepare the two samples for the Q-Q plot, one sample is the C-diet, the other one is the HF-diet.

# %%
# cd samples
randSampleCD = [cd for cd in editAvExprData.ix[randGene].index if cd.endswith("CD")]

# hfd samples
randSampleHFD = [hfd for hfd in editAvExprData.ix[randGene].index if hfd.endswith("HFD")]

# strains which are in both of the samples
commonSamples = [sample for sample in [str(cd).replace("CD", "") for cd in randSampleCD] 
                 if sample in [str(hfd).replace("HFD", "") for hfd in randSampleHFD]]

# sample selections
randSampleCD = editAvExprData.ix[randGene][[strain + "CD" for strain in commonSamples]]
randSampleHFD = editAvExprData.ix[randGene][[strain + "HFD" for strain in commonSamples]]

# %% [markdown]
# Write a function to draw the Q-Q plot

# %%
def qqPlot(sampleA, sampleB, nameA="A", nameB="B"):
    '''
    function to draw a qq-plot
    
    sampleA/sampleB
        numerical list or similar of values for sample A/B
    nameA/nameB
        string of the name of the sample, by default A/B
    function returns the visual output of a plot
    '''
    # initialise the plot
    plt.figure(figsize=(8, 8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")  

    # draw the qq plot
    sm.qqplot_2samples(sampleA, sampleB, ax=ax, line="45")
        
    # visual settings and output of the plot
    plt.xlabel("Quantiles of sample " + nameA, fontsize=16)
    plt.ylabel("Quantiles of sample " + nameB, fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(True, color="lightgrey")
    plt.title("Q-Q plot of " + nameA + " and " + nameB, fontsize=18)
    plt.show();

# %% [markdown]
# Apply the function onto the two prepared samples of a random gene.

# %%
qqPlot(randSampleCD, randSampleHFD, "CD", "HFD")

# %% [markdown]
# #### Subsubtask 2.1.3: Apply an appropriate statistical test in order to figure out whether the samples have equal variance (there may be more than one sensible solution)

# %%
print bartlett(randSampleCD, randSampleHFD)
print levene(randSampleCD, randSampleHFD)
# Out:
# BartlettResult(statistic=0.34821594933898814, pvalue=0.55512477936069304)
# LeveneResult(statistic=0.19343113480003674, pvalue=0.66132429539417181)

# %% [markdown]
# According to the Bartlett and Levene test the two samples of the random gene have an equal variance. Because both p-values are higher 0.5. therefore they are not significant and the variance is not unequal.
# The Bartlett test shows a smaller p-value than the Levene test because it is a stricter test than the Levene test. Due to that the Bartlett test will be used for further tests.

# %% [markdown]
# #### Subsubtask 2.1.4: To asses the global situation, plot a histogram of p-values for all the genes (using the same test you chose in 2.1.3)

# %% [markdown]
# Analyse the variance between the samples over all genes with the Bartlett-test and store the p-values in a list.

# %%
pVals = [bartlett(np.array(editAvExprData.loc[gene][[strain + "CD" for strain in commonSamples]].T), 
                  np.array(editAvExprData.loc[gene][[strain + "HFD" for strain in commonSamples]].T)).pvalue
         for gene in editAvExprData.index.values]

# %% [markdown]
# Write a function to plot p-value histogrames and apply it onto the computed p-values of the Bartlett-test.

# %%
def pValHist(plist, test=""):
    '''
    function to plot a histogram over pvalues
    
    plist
        numerical list of p-values
    test
        String name of the test, by default ""
    the function returns the visual output of the p-value histogram
    '''
    # initialise the plot
    plt.figure(figsize=(15, 8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")

    # plot the histogram with 20 bins to see the possible significance level 0.05
    plt.hist(plist, bins=20)

    # settings of the plot
    plt.ylabel("Abs. frequency", fontsize=14)
    plt.xlabel("$p$-values", fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(test + " test p-values", fontsize=16)
    plt.grid(True, color="lightgrey")

    plt.show();

# %%
pValHist(pVals, "Bartlett")

# %% [markdown]
# As visible about 2100 genes have a p-value of smaller 0.05, with an $\alpha$ of 0.05 as significance level, this 2100 genes would not have an equal variance. This has to be taken in account for further statistical analysis.

# %% [markdown]
# ### Subtask 2.2 Are the CD and HFD samples normally distributed?

# %% [markdown]
# Utterly shocked and overwhelmed by ambiguous emotions you begin to doubt the wisdom of Josef-Francisco and start a top-secret and highly dangerous investigation whether the samples are at least normally distributed. Be careful whom you'll tell about that you're working on this...

# %% [markdown]
# #### Subsubtask 2.2.1: Using the same gene randomly chosen above, make a Box plot for the corresponding CD and HFD sample and give an interpretation

# %%
# initialise the plot
plt.figure(figsize=(15, 8), dpi=80)
ax = plt.gca()
ax.set_axis_bgcolor("white")

# draw the boxplot and therefore merge the two lists back together to a dataframe with two columns
sns.boxplot(pd.DataFrame([np.array(randSampleCD), 
                          np.array(randSampleHFD)], 
                         columns=commonSamples, index=["CD", "HFD"]).T)

# settings of the plot
plt.ylabel("Gene expression values over the strains", fontsize=14)
plt.xlabel("Diet samples", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("Comparison of CD and HFD", fontsize=16)
plt.grid(True, color="lightgrey", axis="y")

plt.show();

# %% [markdown]
# If both samples would be equaly distributed the median of the two samples would be the same. The expression of this random example gene seems therefore not to be equaly distributed. Furthermore the most values of HFD are a slightly higher than those of CD.

# %% [markdown]
# #### Subsubtask 2.2.2: Just like in 2.2.1 make Q-Q plots for each sample (compare each to the theoretical normal distribution) and try an interpretation.

# %%
def qqPlotNorm(sample, name=""):
    '''
    function to draw a qq-plot
    
    sample
        numerical list of the sample which will be plotted against the normal distribution
    name
        string of the name of the sample, by default ""
    function returns the visual output of a plot
    '''
    # initialise the plot
    plt.figure(figsize=(8, 8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")  

    # draw the qq plot of the standardised sample values against the normal distribution
    sm.qqplot(zscore(sample), ax=ax, line="45")
        
    # visual settings and output of the plot
    plt.ylabel("Quantiles of sample " + name, fontsize=16)
    plt.xlabel("Quantiles of the normal distribution", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(True, color="lightgrey")
    plt.title("Q-Q plot of " + name + " against the normal distribution", fontsize=18)
   
    plt.show();

# %%
qqPlotNorm(editAvExprData.ix[randGene][[strain + "CD" for strain in commonSamples]], "CD")

# %%
qqPlotNorm(editAvExprData.ix[randGene][[strain + "HFD" for strain in commonSamples]], "HFD")

# %% [markdown]
# After the standardisation of the distributions of the samples for the random gene, they look very similar to a normal distribution.

# %% [markdown]
# #### Subsubtask 2.2.3: Apply an appropriate statistical test in order to figure out whether the samples are normally distributed (there may be more than one sensible solution)

# %%
normPValsCD = [normaltest(np.array(editAvExprData.loc[gene][[strain + "CD" for strain in commonSamples]].T)).pvalue
               for gene in editAvExprData.index.values]
normPValsHFD = [normaltest(np.array(editAvExprData.loc[gene][[strain + "HFD" for strain in commonSamples]].T)).pvalue
                for gene in editAvExprData.index.values]

# %% [markdown]
# #### Subsubtask 2.2.4: To asses the global situation, plot a histogram of p-values for all the genes (using the same test you chose in 2.2.3)

# %%
pValHist(normPValsCD, "Normal")

# %%
pValHist(normPValsHFD, "Normal")

# %% [markdown]
# The p-values of the normal test show a similar result as the p-values of the Barlett test, a few genes are not normally distributed, if the significance level is assumed to $\alpha$ = 0.05 ($\sim 2500$ for HFD and $\sim 4200$ for CD).

# %% [markdown]
# #### Subsubtask 2.2.5: Write a 1-word essay about whether there is any instrinsic philosophical reason that any data follows a normal distribution

# %% [markdown]
# NO

# %% [markdown]
# ### Subtask 2.3 Choose a suitable statistical test to assess differential expression, apply it to every row, store the results in a suitable dataframe (you may want to order the genes with respect to their p-values) and finally extract a list of differentially expressed genes (5% significance). How many differentially expressed genes do you get?

# %% [markdown]
# Due to the fact, that we cannot assume a normal distribution and a equal variance for all of the expression values, the Mann-Whitney-U-test will be applied instead of the t-test.

# %%
difExpr = [mannwhitneyu(np.array(editAvExprData.loc[gene][[strain + "CD" for strain in commonSamples]].T), 
                        np.array(editAvExprData.loc[gene][[strain + "HFD" for strain in commonSamples]].T)).pvalue
           for gene in editAvExprData.index.values]

# %% [markdown]
# Store the p-values into a dataframe.

# %%
difExpr = pd.DataFrame(difExpr, index=editAvExprData.index.values, columns=["p_value"])

# %% [markdown]
# Sort the dataframe and report all genes with a p-value $\leq$ 0.05

# %%
difExprGenes = difExpr[difExpr.p_value < 0.05]
len(difExprGenes)
# Out:
# 13460

# %% [markdown]
# As visible from the previous test 13460 genes are differentially expressed in the dataset, according to the Mann-Whitney-U-test and an $\alpha$ of 0.05.

# %% [markdown]
# ## Task 3: Multiple-testing correction

# %% [markdown]
# You receive an anonymous letter revealing to you that you should do multiple-testing correction, otherwise something awfully bad will happen, or not. Puzzled and shaking you embark on this endeavour.
#
# Fredholm, your lab's vodoo priest, is convinced that applying anything else than Bonferroni correction brings death and destruction to the people on the moon. Opportunistically neglecting any potential societal consequences of your actions (technology is neutral after all and who cares about the moon anyway!) you're obsessed to try as many multiple testing procedures as possible.
#
# Everything you may need, is most likely found here:
#
# http://statsmodels.sourceforge.net/stable/stats.html#multiple-tests-and-multiple-comparison-procedures

# %% [markdown]
# ### Subtask 3.1: For your official report you have to pretend to care about Bonferroni's correction (otherwise it will never pass through Fredholm's office): manually code it (do not use the statsmodels implementation for example) and store the results in a suitable dataframe. How many differentially expressed gene do you get?

# %%
def bonf(pvals, alpha=0.05):
    '''
    function to conduct the bonferroni correction onto a set of p-values
    
    pval
        pandas dataframe which contains the column p_value, which contains the to examined p-values
    alpha
        float significance level of the computation, by default 0.05
        
    the function returns the rows of the dataframe which contain differentially expressed genes
    '''
    
    k = len(pvals.index)
    cor_alpha = alpha / k
    
    return pvals[pvals.p_value < cor_alpha]

# %%
len(bonf(difExpr))
# Out:
# 3093

# %% [markdown]
# There are 3093 differentially expressed genes in the dataset after the Multiple-testing correction with Bonferroni.

# %% [markdown]
# ### Subtask 3.2: Apply all multiple testing procedures you can get your hands on (except Bonferroni; now you should use statsmodels) to your uncorrected p-values and store the results in one (!) dataframe.

# %%
tests = ["sidak", "holm-sidak", "holm", "simes-hochberg", "hommel", 
         "fdr_bh", "fdr_by", "fdr_tsbh" , "fdr_tsbky"]

# %%
mhtPVals = difExpr.copy()

# %%
for t in tests:
    res = multipletests(difExpr.p_value.values, alpha=0.05, method=t)
    res = pd.DataFrame([res[1]], index =[t + "_cor_pval"], columns=difExpr.index).T
    mhtPVals = mhtPVals.join(res)

# %%
mhtPVals.head()
# Out:
#                p_value  sidak_cor_pval  holm-sidak_cor_pval  holm_cor_pval  \
# Igh       8.634098e-08    1.883393e-03         1.720503e-03   1.721984e-03
# Hcfc2     8.742707e-05    8.517664e-01         7.667686e-01   1.000000e+00
# Ccdc112   1.072951e-11    2.342685e-07         2.305239e-07   2.305236e-07
# EG635895  7.292464e-07    1.579628e-02         1.394280e-02   1.404091e-02
# Srp72     3.539137e-01    1.000000e+00         1.000000e+00   1.000000e+00
#
#           simes-hochberg_cor_pval  hommel_cor_pval  fdr_bh_cor_pval  \
# Igh                  1.721725e-03     1.517184e-03     9.953373e-07
# Hcfc2                5.000000e-01     4.995801e-01     3.677223e-04
# Ccdc112              2.305129e-07     2.250516e-07     6.657274e-10
# EG635895             1.404091e-02     1.153522e-02     6.165232e-06
# Srp72                5.000000e-01     5.000000e-01     3.899639e-01
#
#           fdr_by_cor_pval  fdr_tsbh_cor_pval  fdr_tsbky_cor_pval
# ...

# %% [markdown]
# ### Subtask 3.3: External visual comparison of the different methods
# 1 Write the DE dataframe to a csv file.
# 2 add a row with either 'numeric' or 'factor' as the first row to describe the data schema and save the file
# 3 use [paco](http://parallelcoordinates.de/paco) to visualize your data in parallel coordinates
# 4 which of the multiple testing methods is the most stringent? What's the relation between the others?

# %% [markdown]
# Create the "numeric" row as dataframe and join the dataframe with the p-values to this dataframe, as final dataframe.

# %%
firstRow = pd.DataFrame([["numeric"]*len(mhtPVals.columns)], index=["firstRow"], columns=mhtPVals.columns.values)

# %%
finalMHTValues = firstRow.append(mhtPVals)

# %% [markdown]
# Write the final MHT file to a csv file.

# %%
finalMHTValues.drop("p_values", axis=1).to_csv(DIR + "DifferentMHTs.csv", na_rep="x", index=False)

# %% [markdown]
# The most stringent testing method is, in this case, simes-hochberg, whereas the fdr methods are the most lenient. Beside fdr_by the fdr methods report the same result. Furthermore it is visible, that the computed p-values are differing in their height, but not their order. There are no crossed lines in the parallel coordinate plot.

# %% [markdown]
# ### Subtask 3.4: Select a random method applied in 3.2 and extract the corresponding list of differentially expressed genes. Is this list contain more or less genes than the list from 2.3? Does it contain more or less genes than your Bonferroni list? ;)

# %%
randMethod = random.choice(finalMHTValues.columns.values)
print randMethod
print len(finalMHTValues[finalMHTValues[randMethod] < 0.05])
# Out:
# sidak_cor_pval
# 3108

# %% [markdown]
# The Sidak method (which was the random extracted method while creating that comment) contains 3108 differentially expressed genes. This is much less than the 13460 differentially expressed genes without any multiple hypothesis testing but more than the 3093 differentially expressed genes after applying Bonferroni onto the dataset.

# %% [markdown]
# ## Task 4: Vulcano plots

# %% [markdown]
# Marie de la Stratonovich, the devious intellectual opponent of your (former) beloved idol Josef-Francisco Del-Marre-Doyle just received the glorious Popel prize (the first marsian scientist ever to reveive that prize) for copy-pasting the content of the following papers:
#
# 1) arXiv:1103.3434 (https://arxiv.org/abs/1103.3434)
#
# 2) http://www.ncbi.nlm.nih.gov/pubmed/23602812 (doi:10.1016/j.compbiolchem.2013.02.003)
#
# Overwhelmed by these achievments (and motivated by your ever declining esteem for Josef-Francisco) your're immensely excited about the joyous prospect of carrying out out the following tasks:

# %% [markdown]
# ### Subtask 4.1: Add a log2 fold change column to the data frame from 3.2 and store it as a csv file.

# %%
logTwoFoldChange = finalMHTValues.copy()

# %% [markdown]
# Compute the log2 fold change of the two samples CD and HFD by computing (log$_2$(mean(CD)) - log$_2$(mean(HFD))) for each gene.

# %%
logTwoFC = [np.log2(np.mean(np.array(editAvExprData.loc[gene][[strain + "CD" for strain in commonSamples]].T))) -  
            np.log2(np.mean(np.array(editAvExprData.loc[gene][[strain + "HFD" for strain in commonSamples]].T)))
            for gene in editAvExprData.index.values]

# %%
logTwoFoldChange = logTwoFoldChange.drop("firstRow", axis=0).join(pd.DataFrame(logTwoFC,
                                                                               columns=["log2FC"], 
                                                                               index=[difExpr.index.values]))

# %% [markdown]
# ### Subtask 4.2:  Implement a Vulcano plot (from scratch using matplotlib)

# %%
def volcano(pvals, logtwofc):
    '''
    function to print a volcano plot
    
    pvals
        numerical list or np.array which contains the p-values
    logtwofc
        numerical list or np.array which contains the log2 foldchange
        
    the function returns a plot of a volcano plot
    '''
    # write list to np.array if neccessary
    # due to a misterious error the -log10 p-val has to be computed like that
    pvals = -np.log10(np.array([float(p) for p in pvals]))
    logtwofc = np.array(logtwofc)
    
    # initialise the plot
    plt.figure(figsize=(15, 8), dpi=80)
    ax = plt.gca()
    ax.set_axis_bgcolor("white")

    plt.scatter(logtwofc, pvals)

    # settings of the plot
    plt.xlabel("log$_2$ fold change", fontsize=14)
    plt.ylabel("log$_{10}$ p-values", fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title("Volcano plot", fontsize=16)
    plt.grid(True, color="lightgrey", axis="y")

    plt.show();

# %% [markdown]
# ### Subtask 4.3: Apply your Volcano plot implementation to the uncorrected p-values, as well as the corrected p-values from 3.4 (you should have two plots in the end ;))

# %%
volcano(logTwoFoldChange[randMethod].values, logTwoFoldChange.log2FC.values)

# %%
volcano(logTwoFoldChange.p_value.values, logTwoFoldChange.log2FC.values)

# %% [markdown]
# ## Task 5: RNA-seq

# %% [markdown]
# There are faint rumours that some supposedly revolutionary technology could also be used to study gene expression. Find out the name of that technology and outline the most striking difference of that technology compared to microarrays from a statistical modeling point of view.
